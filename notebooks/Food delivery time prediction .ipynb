# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./data/finalTrain.csv',parse_dates=["Order_Date"],dayfirst=True)
df.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude Order_Date Time_Orderd Time_Order_picked  \
# ...

# %% [markdown]
# # creating duplicate DataFrame

# %%
df1 = df.copy()

# %%
df1.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude Order_Date Time_Orderd Time_Order_picked  \
# ...

# %%
drop_features=['ID',	'Delivery_person_ID']
df1.drop(drop_features,inplace=True,axis=1)
df1.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                 36.0                      4.2            30.327968
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
# 3                 34.0                      4.3            30.899584
# 4                 24.0                      4.7            26.463504
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             78.046106                   30.397968
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
# 3             75.809346                   30.919584
# 4             80.372929                   26.593504
#
#    Delivery_location_longitude Order_Date Time_Orderd Time_Order_picked  \
# 0                    78.116106 2022-02-12       21:55             22:10
# 1                    76.347589 2022-02-13       14:55             15:05
# ...

# %%
df1.isna().sum()
# Out:
# Delivery_person_Age            1854
# Delivery_person_Ratings        1908
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weather_conditions              616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken (min)                  0
# dtype: int64

# %% [markdown]
# # dropping empty Time_Order

# %%
df1.dropna(subset=['Time_Orderd'], inplace=True)

# %%
df1.isna().sum()
# Out:
# Delivery_person_Age             214
# Delivery_person_Ratings         268
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                       0
# Time_Order_picked                 0
# Weather_conditions                0
# Road_traffic_density              0
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             943
# Festival                        219
# City                           1144
# Time_taken (min)                  0
# dtype: int64

# %% [markdown]
# # Handling time features

# %%
time_features = ['Time_Orderd','Time_Order_picked']
# creating multiple columns of hours and minutes
for time_feature in time_features:
  df1[time_feature] = df1[time_feature].apply(lambda x: str(int(float(x) * 24)) + ':' + str(int((float(x) * 24 * 60) % 60)) if pd.notna(x) and ':' not in str(x) else x)
  df1[time_feature+'_Hour'] = df1[time_feature].str.split(':', expand=True)[0]
  df1[time_feature+'_Minutes'] = df1[time_feature].str.split(':', expand=True)[1]
  df1[time_feature+'_Hour'] = pd.to_numeric(df1[time_feature+'_Hour'], errors='coerce')
  df1[time_feature+'_Minutes'] = pd.to_numeric(df1[time_feature+'_Minutes'], errors='coerce')

df1.drop(time_features,axis=1,inplace=True)

# %%
df1.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                 36.0                      4.2            30.327968
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
# 3                 34.0                      4.3            30.899584
# 4                 24.0                      4.7            26.463504
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             78.046106                   30.397968
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
# 3             75.809346                   30.919584
# 4             80.372929                   26.593504
#
#    Delivery_location_longitude Order_Date Weather_conditions  \
# 0                    78.116106 2022-02-12                Fog
# 1                    76.347589 2022-02-13             Stormy
# ...

# %%
df1.isna().sum()
# Out:
# Delivery_person_Age             214
# Delivery_person_Ratings         268
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Weather_conditions                0
# Road_traffic_density              0
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             943
# Festival                        219
# City                           1144
# Time_taken (min)                  0
# Time_Orderd_Hour                  0
# Time_Orderd_Minutes               0
# Time_Order_picked_Hour            0
# Time_Order_picked_Minutes         0
# dtype: int64

# %%
df1.dtypes
# Out:
# Delivery_person_Age                   float64
# Delivery_person_Ratings               float64
# Restaurant_latitude                   float64
# Restaurant_longitude                  float64
# Delivery_location_latitude            float64
# Delivery_location_longitude           float64
# Order_Date                     datetime64[ns]
# Weather_conditions                     object
# Road_traffic_density                   object
# Vehicle_condition                       int64
# Type_of_order                          object
# Type_of_vehicle                        object
# multiple_deliveries                   float64
# Festival                               object
# City                                   object
# Time_taken (min)                        int64
# Time_Orderd_Hour                        int64
# Time_Orderd_Minutes                     int64
# Time_Order_picked_Hour                  int64
# Time_Order_picked_Minutes               int64
# dtype: object

# %% [markdown]
# # Handling date feature

# %%
df1['Order_Date'].value_counts()
# Out:
# 2022-03-15    1145
# 2022-04-03    1138
# 2022-03-13    1127
# 2022-03-26    1126
# 2022-03-09    1121
# 2022-03-03    1119
# 2022-03-24    1115
# 2022-03-05    1113
# 2022-04-05    1109
# 2022-03-19    1106
# 2022-03-21    1106
# 2022-03-07    1103
# 2022-03-28    1101
# 2022-04-01    1099
# 2022-03-11    1096
# 2022-03-30    1091
# 2022-03-17    1085
# 2022-03-01    1081
# 2022-03-02     971
# 2022-03-16     957
# 2022-03-06     953
# 2022-03-10     953
# 2022-04-02     949
# 2022-03-20     947
# 2022-03-04     946
# 2022-03-29     943
# 2022-02-11     940
# 2022-03-31     936
# 2022-03-27     935
# 2022-03-18     933
# 2022-03-25     932
# 2022-03-14     932
# 2022-03-23     931
# 2022-03-12     931
# 2022-03-08     923
# 2022-02-13     921
# 2022-04-06     920
# 2022-04-04     910
# 2022-02-17     905
# 2022-02-15     903
# 2022-02-12     836
# 2022-02-16     825
# 2022-02-14     823
# 2022-02-18     817
# Name: Order_Date, dtype: int64

# %%
date_features=['Order_Date']
for date_feature in date_features:
  df1[date_feature+'_Day']= df1[date_feature].dt.day
  df1[date_feature+'_Month'] = df1[date_feature].dt.month
  df1[date_feature+'_Year'] = df1[date_feature].dt.year
  df1[date_feature+'_DayOfWeek'] = df1[date_feature].dt.dayofweek
  df1[date_feature+'_DayOfYear'] = df1[date_feature].dt.dayofyear

df1.drop(date_features,axis=1,inplace=True)

# %%
df1.dtypes
# Out:
# Delivery_person_Age            float64
# Delivery_person_Ratings        float64
# Restaurant_latitude            float64
# Restaurant_longitude           float64
# Delivery_location_latitude     float64
# Delivery_location_longitude    float64
# Weather_conditions              object
# Road_traffic_density            object
# Vehicle_condition                int64
# Type_of_order                   object
# Type_of_vehicle                 object
# multiple_deliveries            float64
# Festival                        object
# City                            object
# Time_taken (min)                 int64
# Time_Orderd_Hour                 int64
# Time_Orderd_Minutes              int64
# Time_Order_picked_Hour           int64
# Time_Order_picked_Minutes        int64
# Order_Date_Day                   int64
# Order_Date_Month                 int64
# Order_Date_Year                  int64
# Order_Date_DayOfWeek             int64
# Order_Date_DayOfYear             int64
# dtype: object

# %%
df1.isna().sum()
# Out:
# Delivery_person_Age             214
# Delivery_person_Ratings         268
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Weather_conditions                0
# Road_traffic_density              0
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             943
# Festival                        219
# City                           1144
# Time_taken (min)                  0
# Time_Orderd_Hour                  0
# Time_Orderd_Minutes               0
# Time_Order_picked_Hour            0
# Time_Order_picked_Minutes         0
# Order_Date_Day                    0
# Order_Date_Month                  0
# Order_Date_Year                   0
# Order_Date_DayOfWeek              0
# Order_Date_DayOfYear              0
# dtype: int64

# %% [markdown]
# # Fill missing values with Scikit-Learn

# %%
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer

numeric_imputer = SimpleImputer(strategy="median")
categorical_imputer = SimpleImputer(strategy="most_frequent")

numeric_features = ['Delivery_person_Age','Delivery_person_Ratings']
categorical_features = ['multiple_deliveries','Festival','City']

n_imputer = ColumnTransformer([
    ('numerical_imputer',numeric_imputer,numeric_features),
])
c_imputer = ColumnTransformer([
    ('categorical_imputer',categorical_imputer,categorical_features),
])

df1[numeric_features] = n_imputer.fit_transform(df1)# transforming saparately since dtypes gets changed when combined
df1[categorical_features] = c_imputer.fit_transform(df1)

# %%
df1.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                 36.0                      4.2            30.327968
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
# 3                 34.0                      4.3            30.899584
# 4                 24.0                      4.7            26.463504
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             78.046106                   30.397968
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
# 3             75.809346                   30.919584
# 4             80.372929                   26.593504
#
#    Delivery_location_longitude Weather_conditions Road_traffic_density  \
# 0                    78.116106                Fog                  Jam
# 1                    76.347589             Stormy                 High
# ...

# %%
df1.isna().sum()
# Out:
# Delivery_person_Age            0
# Delivery_person_Ratings        0
# Restaurant_latitude            0
# Restaurant_longitude           0
# Delivery_location_latitude     0
# Delivery_location_longitude    0
# Weather_conditions             0
# Road_traffic_density           0
# Vehicle_condition              0
# Type_of_order                  0
# Type_of_vehicle                0
# multiple_deliveries            0
# Festival                       0
# City                           0
# Time_taken (min)               0
# Time_Orderd_Hour               0
# Time_Orderd_Minutes            0
# Time_Order_picked_Hour         0
# Time_Order_picked_Minutes      0
# Order_Date_Day                 0
# Order_Date_Month               0
# Order_Date_Year                0
# Order_Date_DayOfWeek           0
# Order_Date_DayOfYear           0
# dtype: int64

# %% [markdown]
# # Encoding

# %%
df1.dtypes
# Out:
# Delivery_person_Age            float64
# Delivery_person_Ratings        float64
# Restaurant_latitude            float64
# Restaurant_longitude           float64
# Delivery_location_latitude     float64
# Delivery_location_longitude    float64
# Weather_conditions              object
# Road_traffic_density            object
# Vehicle_condition                int64
# Type_of_order                   object
# Type_of_vehicle                 object
# multiple_deliveries             object
# Festival                        object
# City                            object
# Time_taken (min)                 int64
# Time_Orderd_Hour                 int64
# Time_Orderd_Minutes              int64
# Time_Order_picked_Hour           int64
# Time_Order_picked_Minutes        int64
# Order_Date_Day                   int64
# Order_Date_Month                 int64
# Order_Date_Year                  int64
# Order_Date_DayOfWeek             int64
# Order_Date_DayOfYear             int64
# dtype: object

# %%
df1['multiple_deliveries']=df1['multiple_deliveries'].astype('int')

# %%
df1.dtypes
# Out:
# Delivery_person_Age            float64
# Delivery_person_Ratings        float64
# Restaurant_latitude            float64
# Restaurant_longitude           float64
# Delivery_location_latitude     float64
# Delivery_location_longitude    float64
# Weather_conditions              object
# Road_traffic_density            object
# Vehicle_condition                int64
# Type_of_order                   object
# Type_of_vehicle                 object
# multiple_deliveries              int64
# Festival                        object
# City                            object
# Time_taken (min)                 int64
# Time_Orderd_Hour                 int64
# Time_Orderd_Minutes              int64
# Time_Order_picked_Hour           int64
# Time_Order_picked_Minutes        int64
# Order_Date_Day                   int64
# Order_Date_Month                 int64
# Order_Date_Year                  int64
# Order_Date_DayOfWeek             int64
# Order_Date_DayOfYear             int64
# dtype: object

# %%
df1.shape
# Out:
# (43853, 24)

# %%
from sklearn.preprocessing import OrdinalEncoder
ordinal_features = ['Weather_conditions', 'Road_traffic_density', 'Type_of_order', 'Type_of_vehicle', 'Festival', 'City']
ordinal = OrdinalEncoder()
transformer = ColumnTransformer([("ordinal",
                                 ordinal,
                                 ordinal_features)])
df1[ordinal_features] = transformer.fit_transform(df1)

# %%
df1.head().T
# Out:
#                                        0            1            2  \
# Delivery_person_Age            36.000000    21.000000    23.000000
# Delivery_person_Ratings         4.200000     4.700000     4.700000
# Restaurant_latitude            30.327968    10.003064    18.562450
# Restaurant_longitude           78.046106    76.307589    73.916619
# Delivery_location_latitude     30.397968    10.043064    18.652450
# Delivery_location_longitude    78.116106    76.347589    74.006619
# Weather_conditions              1.000000     3.000000     2.000000
# Road_traffic_density            1.000000     0.000000     3.000000
# Vehicle_condition               2.000000     1.000000     1.000000
# Type_of_order                   3.000000     2.000000     1.000000
# Type_of_vehicle                 1.000000     1.000000     2.000000
# multiple_deliveries             3.000000     1.000000     1.000000
# Festival                        0.000000     0.000000     0.000000
# ...

# %%
df1.dtypes
# Out:
# Delivery_person_Age            float64
# Delivery_person_Ratings        float64
# Restaurant_latitude            float64
# Restaurant_longitude           float64
# Delivery_location_latitude     float64
# Delivery_location_longitude    float64
# Weather_conditions             float64
# Road_traffic_density           float64
# Vehicle_condition                int64
# Type_of_order                  float64
# Type_of_vehicle                float64
# multiple_deliveries              int64
# Festival                       float64
# City                           float64
# Time_taken (min)                 int64
# Time_Orderd_Hour                 int64
# Time_Orderd_Minutes              int64
# Time_Order_picked_Hour           int64
# Time_Order_picked_Minutes        int64
# Order_Date_Day                   int64
# Order_Date_Month                 int64
# Order_Date_Year                  int64
# Order_Date_DayOfWeek             int64
# Order_Date_DayOfYear             int64
# dtype: object

# %% [markdown]
# # converting all preprocessing into function

# %%
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OrdinalEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

def handle_time_feature(df):
  time_features = ['Time_Orderd','Time_Order_picked']
  # creating multiple columns of hours and minutes
  for time_feature in time_features:
    df[time_feature] = df[time_feature].apply(lambda x: str(int(float(x) * 24)) + ':' + str(int((float(x) * 24 * 60) % 60)) if pd.notna(x) and ':' not in str(x) else x)
    df[time_feature+'_Hour'] = df[time_feature].str.split(':', expand=True)[0]
    df[time_feature+'_Minutes'] = df[time_feature].str.split(':', expand=True)[1]
    df[time_feature+'_Hour'] = pd.to_numeric(df[time_feature+'_Hour'], errors='coerce')
    df[time_feature+'_Minutes'] = pd.to_numeric(df[time_feature+'_Minutes'], errors='coerce')

  df.drop(time_features,axis=1,inplace=True)
  return df

def handle_date_feature(df):
  # creating multiple columns of date
  date_features=['Order_Date']
  for date_feature in date_features:
    df[date_feature+'_Day']= df[date_feature].dt.day
    df[date_feature+'_Month'] = df[date_feature].dt.month
    df[date_feature+'_Year'] = df[date_feature].dt.year
    df[date_feature+'_DayOfWeek'] = df[date_feature].dt.dayofweek
    df[date_feature+'_DayOfYear'] = df[date_feature].dt.dayofyear

  df.drop(date_features,axis=1,inplace=True)
  return df


def get_data_transformation_obj():
  numeric_features = ['Delivery_person_Age','Delivery_person_Ratings','multiple_deliveries']
  categorical_features = ['Weather_conditions', 'Road_traffic_density', 'Type_of_order', 'Type_of_vehicle', 'Festival', 'City']

  Weather_conditions=['Sunny','Cloudy','Fog','Windy','Stormy','Sandstorms']
  Road_traffic_density=['Low','Medium','High','Jam']
  Type_of_order=['Snack','Drinks','Meal','Buffet']
  Type_of_vehicle=['bicycle','motorcycle','electric_scooter','scooter']
  Festival=['No','Yes']
  City=['Semi-Urban','Urban','Metropolitian']

  ## Numerical Pipeline
  num_pipeline = Pipeline(
      steps=[
          ('imputer',SimpleImputer(strategy='median')),
      ]
  )

   ## Categorical pipeline
  categorical_pipeline= Pipeline(
      steps = [
          ('imputer',SimpleImputer(strategy='most_frequent')),
          ('ordinalencoder',OrdinalEncoder(categories=[Weather_conditions,
                                                       Road_traffic_density,
                                                       Type_of_order,
                                                       Type_of_vehicle,
                                                       Festival,
                                                       City])),
      ]
  )

  preprocessor = ColumnTransformer([
      ('num_pipeline',num_pipeline,numeric_features),
      ('categorical_pipeline',categorical_pipeline,categorical_features),
  ])
  return preprocessor

def preprocessing(df):
  numeric_features = ['Delivery_person_Age','Delivery_person_Ratings','multiple_deliveries']
  categorical_features = ['Weather_conditions', 'Road_traffic_density', 'Type_of_order', 'Type_of_vehicle', 'Festival', 'City']
  drop_features=['ID',	'Delivery_person_ID']

  df.dropna(subset=['Time_Orderd'], inplace=True)

  X = df.drop('Time_taken (min)',axis=1)
  y = df['Time_taken (min)']

  X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=0.3,random_state=42)


  X_train.drop(drop_features,axis=1,inplace=True)
  X_test.drop(drop_features,axis=1,inplace=True)

  X_train=handle_time_feature(X_train)
  X_test=handle_time_feature(X_test)

  X_train=handle_date_feature(X_train)
  X_test=handle_date_feature(X_test)

  X_train['multiple_deliveries'] = X_train['multiple_deliveries'].astype('float')
  X_test['multiple_deliveries'] = X_test['multiple_deliveries'].astype('float')

  preprocessor = get_data_transformation_obj()

  X_train[numeric_features+categorical_features] = preprocessor.fit_transform(X_train)
  X_test[numeric_features+categorical_features] = preprocessor.transform(X_test)

  return X_train,X_test,y_train,y_test

# %% [markdown]
# # Spliting data into test and train

# %%
from sklearn.model_selection import train_test_split
df2 = df.copy()
X_train, X_test, y_train, y_test = preprocessing(df2)
X_train.shape
# Out:
# (30697, 23)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (30697, 23)
# (30697,)
# (13156, 23)
# (13156,)

# %%
X_test.head().T
# Out:
#                                    37999    28033        30333        8291   \
# Delivery_person_Age            26.000000    26.00    28.000000    22.000000
# Delivery_person_Ratings         5.000000     4.60     5.000000     4.600000
# Restaurant_latitude            26.913483     0.00    17.422819    17.483216
# Restaurant_longitude           75.803139     0.00    78.449578    78.552111
# Delivery_location_latitude     26.953483     0.05    17.472819    17.573216
# Delivery_location_longitude    75.843139     0.05    78.499578    78.642111
# Weather_conditions              0.000000     1.00     1.000000     5.000000
# Road_traffic_density            1.000000     3.00     3.000000     0.000000
# Vehicle_condition               0.000000     2.00     2.000000     0.000000
# Type_of_order                   0.000000     2.00     1.000000     1.000000
# Type_of_vehicle                 1.000000     3.00     2.000000     1.000000
# ...

# %%
print(X_train.isna().sum())
print(X_test.isna().sum())
# Out:
# Delivery_person_Age            0
# Delivery_person_Ratings        0
# Restaurant_latitude            0
# Restaurant_longitude           0
# Delivery_location_latitude     0
# Delivery_location_longitude    0
# Weather_conditions             0
# Road_traffic_density           0
# Vehicle_condition              0
# Type_of_order                  0
# Type_of_vehicle                0
# multiple_deliveries            0
# Festival                       0
# City                           0
# Time_Orderd_Hour               0
# Time_Orderd_Minutes            0
# Time_Order_picked_Hour         0
# Time_Order_picked_Minutes      0
# Order_Date_Day                 0
# Order_Date_Month               0
# Order_Date_Year                0
# Order_Date_DayOfWeek           0
# Order_Date_DayOfYear           0
# dtype: int64
# Delivery_person_Age            0
# Delivery_person_Ratings        0
# Restaurant_latitude            0
# Restaurant_longitude           0
# Delivery_location_latitude     0
# ...

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.ensemble import RandomForestRegressor

models = {
    "LinearRegression": LinearRegression(),
    "Ridge": Ridge(),
    "Lasso": Lasso(),
    "ElasticNet": ElasticNet(),
    "RandomForest": RandomForestRegressor()
}

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
def train_model(model_name, model, x_train= X_train, x_test = X_test, y_train = y_train, y_test = y_test):
    print("#"*50)
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    print(model_name,":")
    print("r2_score", r2_score(y_test, y_pred))
    print("mean squared error", ":", mean_squared_error(y_pred, y_test))
    print("mean absolute error", ":", mean_absolute_error(y_pred, y_test))
    print("root mean squared error", ":", np.sqrt(mean_squared_error(y_pred, y_test)))

# %%
for model_name, model in models.items():
    train_model(model_name,model)
# Out:
# ##################################################
# LinearRegression :
# r2_score 0.5352354134703383
# mean squared error : 40.94915486048748
# mean absolute error : 5.084229139869041
# root mean squared error : 6.399152667383978
# ##################################################
# Ridge :
# r2_score 0.5348392117944698
# mean squared error : 40.98406312211359
# mean absolute error : 5.085231421539667
# root mean squared error : 6.401879655391344
# ##################################################
# Lasso :
# r2_score 0.3472892454432439
# mean squared error : 57.508585081803425
# mean absolute error : 6.110038279961403
# root mean squared error : 7.583441506453612
# ##################################################
# ElasticNet :
# r2_score 0.34261658426729946
# mean squared error : 57.9202806619961
# mean absolute error : 6.137308217910951
# root mean squared error : 7.610537475237613
# ##################################################
# RandomForest :
# ...

# %% [markdown]
# # Training using distance

# %%
from math import radians, sin, cos, sqrt, atan2

def calculate_distance(lat1, lon1, lat2, lon2):
    # Convert latitude and longitude from degrees to radians
    lat1 = radians(lat1)
    lon1 = radians(lon1)
    lat2 = radians(lat2)
    lon2 = radians(lon2)

    # Earth's radius in kilometers
    radius = 6371

    # Calculate the differences in latitude and longitude
    dlat = lat2 - lat1
    dlon = lon2 - lon1

    # Apply the Haversine formula
    a = sin(dlat / 2) ** 2 + cos(lat1) * cos(lat2) * sin(dlon / 2) ** 2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    # Calculate the distance
    distance = radius * c

    return distance

# %%
df3 = df.copy()
df3['Distance'] = df.apply(lambda row: calculate_distance(row['Restaurant_latitude'], row['Restaurant_longitude'], row['Delivery_location_latitude'], row['Delivery_location_longitude']), axis=1)
df3.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
# ...

# %%
def get_distance(df):
  df['Distance'] = df.apply(lambda row: calculate_distance(row['Restaurant_latitude'], row['Restaurant_longitude'], row['Delivery_location_latitude'], row['Delivery_location_longitude']), axis=1)
  df.drop(['Restaurant_latitude','Restaurant_longitude','Delivery_location_latitude','Delivery_location_longitude'],inplace=True,axis=1)
  return df

# %%
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OrdinalEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

def handle_time_feature(df):
  time_features = ['Time_Orderd','Time_Order_picked']
  # creating multiple columns of hours and minutes
  for time_feature in time_features:
    df[time_feature] = df[time_feature].apply(lambda x: str(int(float(x) * 24)) + ':' + str(int((float(x) * 24 * 60) % 60)) if pd.notna(x) and ':' not in str(x) else x)
    df[time_feature+'_Hour'] = df[time_feature].str.split(':', expand=True)[0]
    df[time_feature+'_Minutes'] = df[time_feature].str.split(':', expand=True)[1]
    df[time_feature+'_Hour'] = pd.to_numeric(df[time_feature+'_Hour'], errors='coerce')
    df[time_feature+'_Minutes'] = pd.to_numeric(df[time_feature+'_Minutes'], errors='coerce')

  df.drop(time_features,axis=1,inplace=True)
  return df

def handle_date_feature(df):
  # creating multiple columns of date
  date_features=['Order_Date']
  for date_feature in date_features:
    df[date_feature+'_Day']= df[date_feature].dt.day
    df[date_feature+'_Month'] = df[date_feature].dt.month
    df[date_feature+'_Year'] = df[date_feature].dt.year
    df[date_feature+'_DayOfWeek'] = df[date_feature].dt.dayofweek
    df[date_feature+'_DayOfYear'] = df[date_feature].dt.dayofyear

  df.drop(date_features,axis=1,inplace=True)
  return df


def get_data_transformation_obj():
  numeric_features = [
      'Delivery_person_Age','Delivery_person_Ratings','multiple_deliveries',
      'Distance','Time_Orderd_Hour','Time_Orderd_Minutes','Time_Order_picked_Hour',
      'Time_Order_picked_Minutes','Order_Date_Day','Order_Date_Month','Order_Date_Year',
      'Order_Date_DayOfWeek','Order_Date_DayOfYear']
  categorical_features = ['Weather_conditions', 'Road_traffic_density', 'Type_of_order', 'Type_of_vehicle', 'Festival', 'City']

  Weather_conditions=['Sunny','Cloudy','Fog','Windy','Stormy','Sandstorms']
  Road_traffic_density=['Low','Medium','High','Jam']
  Type_of_order=['Snack','Drinks','Meal','Buffet']
  Type_of_vehicle=['bicycle','motorcycle','electric_scooter','scooter']
  Festival=['No','Yes']
  City=['Semi-Urban','Urban','Metropolitian']

  ## Numerical Pipeline
  num_pipeline = Pipeline(
      steps=[
          ('imputer',SimpleImputer(strategy='median')),
          ('scaler',StandardScaler())
      ]
  )

   ## Categorical pipeline
  categorical_pipeline= Pipeline(
      steps = [
          ('imputer',SimpleImputer(strategy='most_frequent')),
          ('ordinalencoder',OrdinalEncoder(categories=[Weather_conditions,
                                                       Road_traffic_density,
                                                       Type_of_order,
                                                       Type_of_vehicle,
                                                       Festival,
                                                       City])),
          ('scaler',StandardScaler())
      ]
  )

  preprocessor = ColumnTransformer([
      ('num_pipeline',num_pipeline,numeric_features),
      ('categorical_pipeline',categorical_pipeline,categorical_features),
  ])
  return preprocessor

def preprocessing(df):
  numeric_features = [
      'Delivery_person_Age','Delivery_person_Ratings','multiple_deliveries',
      'Distance','Time_Orderd_Hour','Time_Orderd_Minutes','Time_Order_picked_Hour',
      'Time_Order_picked_Minutes','Order_Date_Day','Order_Date_Month','Order_Date_Year',
      'Order_Date_DayOfWeek','Order_Date_DayOfYear']
  categorical_features = ['Weather_conditions', 'Road_traffic_density', 'Type_of_order', 'Type_of_vehicle', 'Festival', 'City']
  drop_features=['ID',	'Delivery_person_ID']

  df.dropna(subset=['Time_Orderd'], inplace=True)

  X = df.drop('Time_taken (min)',axis=1)
  y = df['Time_taken (min)']

  X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=0.3,random_state=42)


  X_train.drop(drop_features,axis=1,inplace=True)
  X_test.drop(drop_features,axis=1,inplace=True)
  X_train = get_distance(X_train)
  X_test = get_distance(X_test)

  X_train=handle_time_feature(X_train)
  X_test=handle_time_feature(X_test)

  X_train=handle_date_feature(X_train)
  X_test=handle_date_feature(X_test)

  X_train['multiple_deliveries'] = X_train['multiple_deliveries'].astype('float')
  X_test['multiple_deliveries'] = X_test['multiple_deliveries'].astype('float')

  preprocessor = get_data_transformation_obj()

  X_train[numeric_features+categorical_features] = preprocessor.fit_transform(X_train)
  X_test[numeric_features+categorical_features] = preprocessor.transform(X_test)

  return X_train,X_test,y_train,y_test

# %%
df4 = df.copy()
X_train, X_test, y_train, y_test = preprocessing(df4)
for model_name, model in models.items():
    train_model(model_name,model,X_train, X_test, y_train, y_test)
# Out:
# working1
# working2
# working3
# working2
# ##################################################
# LinearRegression :
# r2_score 0.5009381452571959
# mean squared error : 43.97099470813691
# mean absolute error : 5.25754584633059
# root mean squared error : 6.631062864137008
# ##################################################
# Ridge :
# r2_score 0.5009466827064517
# mean squared error : 43.97024249649725
# mean absolute error : 5.257453247080205
# root mean squared error : 6.631006145110804
# ##################################################
# Lasso :
# r2_score 0.4328355433884936
# mean squared error : 49.97133137566748
# mean absolute error : 5.646240904054675
# root mean squared error : 7.069040343332855
# ##################################################
# ElasticNet :
# r2_score 0.4230710170573433
# mean squared error : 50.83165746862393
# mean absolute error : 5.7173974307778614
# root mean squared error : 7.1296323515749345
# ...

# %%
X_train.head().T
# Out:
#                               8555      21875     45217     38005     29999
# Delivery_person_Age        0.942327 -0.623399  1.116296 -0.971338  0.420418
# Delivery_person_Ratings    0.208048 -0.108615 -0.108615  0.208048  0.208048
# Weather_conditions         0.875137 -1.478214 -0.889876  1.463475  1.463475
# Road_traffic_density       1.300067 -1.111253  1.300067 -0.307480 -1.111253
# Vehicle_condition          2.000000  0.000000  0.000000  1.000000  1.000000
# Type_of_order              1.339750  1.339750  0.448277 -0.443195  0.448277
# Type_of_vehicle           -0.809756 -0.809756 -0.809756  1.351072  1.351072
# multiple_deliveries        0.438110 -1.327733  2.203953  0.438110  0.438110
# Festival                  -0.141073 -0.141073 -0.141073 -0.141073 -0.141073
# City                       0.535562  0.535562  0.535562  0.535562  0.535562
# Distance                  -0.045034 -0.024373 -0.054543 -0.060116 -0.084964
# ...

# %% [markdown]
# #Hyerparameter tuning with RandomizedSearchCV

# %%
# %%time
from sklearn.model_selection import RandomizedSearchCV

# Different RandomForestRegressor hyperparameters
rf_grid = {"n_estimators": np.arange(10, 100, 10),
           "max_depth": [None, 3, 5, 10],
           "min_samples_split": np.arange(2, 20, 2),
           "min_samples_leaf": np.arange(1, 20, 2),
           "max_features": [0.5, 1, "sqrt", "auto"]
           }

# Instantiate RandomizedSearchCV model
rs_model = RandomizedSearchCV(RandomForestRegressor(n_jobs=-1,
                                                    random_state=42),
                              param_distributions=rf_grid,
                              n_iter=50,
                              cv=5,
                              verbose=True)

# Fit the RandomizedSearchCV model
rs_model.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# ...

# %%
# Find the best model hyperparameters
rs_model.best_params_
# Out:
# {'n_estimators': 70,
#  'min_samples_split': 18,
#  'min_samples_leaf': 1,
#  'max_features': 'auto',
#  'max_depth': 10}

# %%
y_pred = rs_model.predict(X_test)
print('R2_score :', r2_score(y_test,y_pred))
print('mean squared error :', mean_squared_error(y_test,y_pred))
print('mean_absolute_error :', mean_absolute_error(y_test,y_pred))
print('root mean squared error :', np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# R2_score : 0.8422100257393415
# mean squared error : 13.902449280136086
# mean_absolute_error : 3.0143761025112816
# root mean squared error : 3.728598836042312

# %% [markdown]
# Notice that r2_score increased from .833 to .8422 if try for 5 fold and 50 iteration i,e 250 fit

# %% [markdown]
# # Hyperparameter tuning with GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV, train_test_split

grid_search = {'n_estimators': [60,70,80,90,100],
          'max_depth': [8,10,12],
          'max_features': ['auto', 'sqrt'],
          'min_samples_split': [16,18,20,22],
          'min_samples_leaf': [1, 2, 3]}

# Setup GridSearchCV
gs_clf = GridSearchCV(estimator=RandomForestRegressor(n_jobs=-1,random_state=42),
                      param_grid=grid_search,
                      cv=5,
                      verbose=2)

# Fit the GridSearchCV version of clf
gs_clf.fit(X_train, y_train);
# Out:
# Fitting 5 folds for each of 360 candidates, totalling 1800 fits
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=8, max_features=auto, min_samples_leaf=1, min_samples_split=16, n_estimators=60; total time=   3.8s
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# ...

# %%
gs_clf.best_params_
# Out:
# {'max_depth': 10,
#  'max_features': 'auto',
#  'min_samples_leaf': 1,
#  'min_samples_split': 22,
#  'n_estimators': 90}

# %%
gs_y_preds = gs_clf.predict(X_test)
print('R2_score :', r2_score(y_test,gs_y_preds))
print('mean squared error :', mean_squared_error(y_test,gs_y_preds))
print('mean_absolute_error :', mean_absolute_error(y_test,gs_y_preds))
print('root mean squared error :', np.sqrt(mean_squared_error(y_test,gs_y_preds)))
# Out:
# R2_score : 0.8423230445855543
# mean squared error : 13.892491494259414
# mean_absolute_error : 3.0126102367073186
# root mean squared error : 3.7272632713908758

# %% [markdown]
# # Training model with best hyperparameters

# %%
hyp_par= {'max_depth': 10,
 'max_features': 'auto',
 'min_samples_leaf': 1,
 'min_samples_split': 22,
 'n_estimators': 90}
regressor = RandomForestRegressor(**hyp_par)
regressor.fit(X_train,y_train)
y_pred=regressor.predict(X_test)
print('R2_score :', r2_score(y_test,y_pred))
print('mean squared error :', mean_squared_error(y_test,y_pred))
print('mean_absolute_error :', mean_absolute_error(y_test,y_pred))
print('root mean squared error :', np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# R2_score : 0.8424567033819742
# mean squared error : 13.880715178008785
# mean_absolute_error : 3.0104649888600523
# root mean squared error : 3.725683182720826

# %% [markdown]
# Observation:
#
# R2_score: from r2_score value we can conclude that the model was able to reduce 84.24% of total sum of residuals.An R2 score of 0.8424 suggests that your model explains approximately 84.24% of the variance in the delivery time.
#
# mean_absolute error : the model will predict time take with +/- 3 min deviation

# %%
regressor.score(X_test,y_test)
# Out:
# 0.8424567033819742

# %%
regressor.score(X_train,y_train)
# Out:
# 0.8590592951647488

# %% [markdown]
# # checking feature importance

# %%
regressor.feature_importances_
# Out:
# array([9.24619389e-02, 2.37674870e-01, 1.75775281e-01, 1.57776968e-01,
#        7.92179862e-02, 6.21625124e-04, 1.68635311e-04, 1.06691523e-01,
#        9.49515079e-03, 2.99363467e-03, 1.14377890e-01, 1.57609094e-02,
#        1.20801527e-03, 9.16756702e-04, 1.12314961e-03, 1.38569777e-03,
#        9.66780399e-05, 0.00000000e+00, 7.49142619e-04, 1.50414756e-03])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Helper function for plotting feature importance
def plot_features(columns, importances, n=20):
    df = pd.DataFrame({"features": columns, "feature_importance": importances})
    df_sorted = df.sort_values("feature_importance", ascending=False).reset_index(drop=True)

    # Create the bar plot using Seaborn
    ax = sns.barplot(x="feature_importance", y="features", data=df_sorted[:n], orient="h")

    # Add value labels to the bars
    for i, v in enumerate(df_sorted["feature_importance"][:n]):
        ax.text(v, i, f"{v:.3f}", color='black', va='center')

    # Set plot labels and title
    ax.set(xlabel="Feature Importance", ylabel="Features", title="Top Feature Importance")

    # Show the plot
    plt.show()

plot_features(X_train.columns,regressor.feature_importances_)

# %% [markdown]
# observation : from the above graph you can observe that date features of less importance along with type of order, type of vehicle, time ordered in minutes and time ordered picked.
