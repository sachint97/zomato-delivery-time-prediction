# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns

# %% [markdown]
# #Importing Data

# %%
data = pd.read_csv('./data/finalTrain.csv')
data.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# ...

# %%
data.shape
# Out:
# (45584, 20)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45584 entries, 0 to 45583
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           45584 non-null  object
#  1   Delivery_person_ID           45584 non-null  object
#  2   Delivery_person_Age          43730 non-null  float64
#  3   Delivery_person_Ratings      43676 non-null  float64
#  4   Restaurant_latitude          45584 non-null  float64
#  5   Restaurant_longitude         45584 non-null  float64
#  6   Delivery_location_latitude   45584 non-null  float64
#  7   Delivery_location_longitude  45584 non-null  float64
#  8   Order_Date                   45584 non-null  object
#  9   Time_Orderd                  43853 non-null  object
#  10  Time_Order_picked            45584 non-null  object
#  11  Weather_conditions           44968 non-null  object
# ...

# %%
data.describe()
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# count         43730.000000             43676.000000         45584.000000
# mean             29.566911                 4.633774            17.017948
# std               5.815064                 0.334744             8.185674
# min              15.000000                 1.000000           -30.905562
# 25%              25.000000                 4.500000            12.933284
# 50%              30.000000                 4.700000            18.551440
# 75%              35.000000                 4.900000            22.728163
# max              50.000000                 6.000000            30.914057
#
#        Restaurant_longitude  Delivery_location_latitude  \
# count          45584.000000                45584.000000
# mean              70.229684                   17.465480
# std               22.885575                    7.335562
# min              -88.366217                    0.010000
# ...

# %%
data.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age            1854
# Delivery_person_Ratings        1908
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weather_conditions              616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken (min)                  0
# dtype: int64

# %%
data.nunique()
# Out:
# ID                             45584
# Delivery_person_ID              1320
# Delivery_person_Age               22
# Delivery_person_Ratings           28
# Restaurant_latitude              657
# Restaurant_longitude             518
# Delivery_location_latitude      4373
# Delivery_location_longitude     4373
# Order_Date                        44
# Time_Orderd                      176
# Time_Order_picked                193
# Weather_conditions                 6
# Road_traffic_density               4
# Vehicle_condition                  4
# Type_of_order                      4
# Type_of_vehicle                    4
# multiple_deliveries                4
# Festival                           2
# City                               3
# Time_taken (min)                  45
# dtype: int64

# %% [markdown]
# # EDA(Exploratory data analysis)

# %% [markdown]
# # Delivery person age

# %%
sns.histplot(data=data,x='Delivery_person_Age',kde=True)
# Out:
# <Axes: xlabel='Delivery_person_Age', ylabel='Count'>

# %%
sns.boxplot(data=data,x="Delivery_person_Age")
# Out:
# <Axes: xlabel='Delivery_person_Age'>

# %%
sns.scatterplot(x=data['Delivery_person_Age'],y=data['Time_taken (min)'])
# Out:
# <Axes: xlabel='Delivery_person_Age', ylabel='Time_taken (min)'>

# %% [markdown]
# observation : No matter what the age delivery person take around 10 - 55 min for delivery

# %% [markdown]
# # Delivery_person_Ratings

# %%
sns.histplot(data=data,x="Delivery_person_Ratings",kde=True)
# Out:
# <Axes: xlabel='Delivery_person_Ratings', ylabel='Count'>

# %% [markdown]
# observation: most of the ratings fall between 4.4 to 5 and there are few outliers

# %%
sns.boxplot(data=data,x="Delivery_person_Ratings")
# Out:
# <Axes: xlabel='Delivery_person_Ratings'>

# %% [markdown]
# observation : notice there is rating of 6 which is not possible as ratting range between 1-5

# %% [markdown]
# # Weather_conditions

# %%
data['Weather_conditions'].unique()
# Out:
# array(['Fog', 'Stormy', 'Sandstorms', 'Windy', 'Cloudy', 'Sunny', nan],
#       dtype=object)

# %%
x = data['Weather_conditions'].value_counts()
plt.pie(x.values,labels=x.index,autopct='%1.1f%%')
plt.show()

# %% [markdown]
# observation : Notice you have almost equal proportions of data set

# %%
sns.barplot(x= data['Weather_conditions'],y=data['Time_taken (min)'])
# Out:
# <Axes: xlabel='Weather_conditions', ylabel='Time_taken (min)'>

# %% [markdown]
# observation : as expected during sunny time taken is less but time taken should be more during sandstorms, stormy and windy which is unusual.

# %% [markdown]
# # Road_traffic_density

# %%
x=data['Road_traffic_density'].value_counts()
plt.pie(x=x.values,labels = x.index , autopct="%.1f%%")
plt.show()

# %% [markdown]
# observation : most of the trafic is of low or jam state.

# %%
sns.barplot(x=data['Road_traffic_density'],y=data['Time_taken (min)'])
# Out:
# <Axes: xlabel='Road_traffic_density', ylabel='Time_taken (min)'>

# %% [markdown]
# observation : as expected time taken is less of low traffic density and high for traffic jam.

# %% [markdown]
# # Vehicle_condition

# %%
sns.barplot(x=data['Vehicle_condition'],y=data['Time_taken (min)'])
# Out:
# <Axes: xlabel='Vehicle_condition', ylabel='Time_taken (min)'>

# %% [markdown]
# observation : no matter what the vehicle condition the time taken will be around 25-30 min

# %% [markdown]
# # Type_of_order

# %%
data['Type_of_order'].value_counts()
# Out:
# Snack     11530
# Meal      11456
# Drinks    11321
# Buffet    11277
# Name: Type_of_order, dtype: int64

# %%
sns.boxplot(x=data['Type_of_order'],y=data['Time_taken (min)'])
# sns.barplot(x=data['Type_of_order'],y=data['Time_taken (min)'])
# Out:
# <Axes: xlabel='Type_of_order', ylabel='Time_taken (min)'>

# %% [markdown]
# #Type_of_vehicle

# %%
sns.boxplot(x=data['Type_of_vehicle'],y=data['Time_taken (min)'])
# Out:
# <Axes: xlabel='Type_of_vehicle', ylabel='Time_taken (min)'>

# %% [markdown]
# #multiple_deliveries

# %%
x=data['multiple_deliveries'].value_counts()
plt.pie(x=x.values,labels=x.index,autopct="%.1f%%")
plt.show()

# %%
sns.barplot(x=data['multiple_deliveries'],y=data['Time_taken (min)'])
# Out:
# <Axes: xlabel='multiple_deliveries', ylabel='Time_taken (min)'>

# %% [markdown]
# observation : as expected if there is multiple deliveries then time taken will be more.

# %% [markdown]
# # Festival

# %%
x=data['Festival'].value_counts()
plt.pie(x=x.values,labels=x.index,autopct="%.1f%%")
plt.show()

# %%
sns.barplot(x=data['Festival'],y=data['Time_taken (min)'])
# Out:
# <Axes: xlabel='Festival', ylabel='Time_taken (min)'>

# %% [markdown]
# observation : during festival time time take will me more.

# %% [markdown]
# # City

# %%
x=data['City'].value_counts()
plt.pie(x=x.values,labels=x.index,autopct="%.1f%%")
plt.show()

# %%
sns.barplot(x=data['City'],y=data['Time_taken (min)'])
# Out:
# <Axes: xlabel='City', ylabel='Time_taken (min)'>

# %% [markdown]
# # Time_taken (min)

# %%
sns.histplot(data=data,x="Time_taken (min)",kde=True)
# Out:
# <Axes: xlabel='Time_taken (min)', ylabel='Count'>

# %%
sns.boxplot(data=data,x="Time_taken (min)")
# Out:
# <Axes: xlabel='Time_taken (min)'>

# %%
data.columns
# Out:
# Index(['ID', 'Delivery_person_ID', 'Delivery_person_Age',
#        'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Order_Date', 'Time_Orderd',
#        'Time_Order_picked', 'Weather_conditions', 'Road_traffic_density',
#        'Vehicle_condition', 'Type_of_order', 'Type_of_vehicle',
#        'multiple_deliveries', 'Festival', 'City', 'Time_taken (min)'],
#       dtype='object')

# %% [markdown]
# # Automation

# %%
def value_count_norm(df, feature):
    value_count = df[feature].value_counts()
    value_count_norm_1 = df[feature].value_counts(normalize=True) * 100
    value_count_norm_1_concat = pd.concat([value_count, value_count_norm_1], axis=1)
    value_count_norm_1_concat.columns = ['Count', 'Frequency %']
    return value_count_norm_1_concat

# %%
def create_pie_chart(df, feature):
    n = len(value_count_norm(df, feature).index)
    colors = sns.color_palette('pastel')[0:n]
    plt.pie(value_count_norm(df, feature).iloc[:, 1],
            colors = colors, autopct='%1.2f%%',
            labels=value_count_norm(df, feature).index)
    plt.title('{}'.format(feature))
    return plt.show()

# %%
def create_hist_plot(df, feature):
    figure(figsize=(20, 8))
    sns.histplot(df[feature], kde=True)
    plt.title('{}'.format(feature))
    return plt.show()

# %%
def get_info(df, feature):
    match feature:
        case 'Weather_conditions'| 'Road_traffic_density'| 'Vehicle_condition'| 'Type_of_order'| 'Type_of_vehicle'| 'multiple_deliveries'| 'Festival'| 'City':
            print('Description:\n{}'.format(df[feature].describe()))
            print('*'*50)
            print('Object type:\n{}'.format(df[feature].dtype))
            print('*'*50)
            print('Value count:\n{}'.format(value_count_norm(df, feature)))
        case 'Delivery_person_Age'| 'Delivery_person_Ratings':
            print('Description:\n{}'.format((np.abs(df[feature])).describe()))
            print('*'*50)
            print('Object type:{}'.format(df[feature].dtype))
        case _:
            print('Error')

# %%
def get_report(df, feature):
    match feature:
        case 'Weather_conditions'| 'Road_traffic_density'| 'Vehicle_condition'| 'Type_of_order'| 'Type_of_vehicle'| 'multiple_deliveries'| 'Festival'| 'City':
            get_info(df, feature)
            print('*'*50)
            create_pie_chart(df, feature)
        case 'Delivery_person_Age'| 'Delivery_person_Ratings':
            get_info(df, feature)
            print('*'*50)
            create_hist_plot(df, feature)
        case _:
            print("Error")

# %%
get_report(data,'Weather_conditions')
# Out:
# Description:
# count     44968
# unique        6
# top         Fog
# freq       7653
# Name: Weather_conditions, dtype: object
# **************************************************
# Object type:
# object
# **************************************************
# Value count:
#             Count  Frequency %
# Fog          7653    17.018769
# Stormy       7584    16.865326
# Cloudy       7533    16.751912
# Sandstorms   7494    16.665184
# Windy        7422    16.505070
# Sunny        7282    16.193738
# **************************************************

# %%
get_report(data,'Delivery_person_Age')
# Out:
# Description:
# count    43730.000000
# mean        29.566911
# std          5.815064
# min         15.000000
# 25%         25.000000
# 50%         30.000000
# 75%         35.000000
# max         50.000000
# Name: Delivery_person_Age, dtype: float64
# **************************************************
# Object type:float64
# **************************************************

# %% [markdown]
# # Correlation heatmap

# %%
plt.figure(figsize=(10, 10))
corr_matrix = data.corr()
sns.heatmap(corr_matrix,annot=True)
# Out:
# C:\Users\sachin\AppData\Local\Temp\ipykernel_11528\3819839564.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = data.corr()
# <Axes: >
